# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language.
# In simpler terms, syntax is about the correct arrangement of words and symbols in a code
#
# Semantics refers to the meaning or the interpretation of the symbols, characters and commands in a language.
# it is a bout what the code is supposed to do when it runs

# %%
## Basic syntax rules in Python
## case sensitivity- Python is case sensitive.

name = "Kiran"
Name = "John"

print(name)  # Output: Kiran
print(Name)  # Output: John
# Out:
# Kiran
# John

# %% [markdown]
# Indentation
# Indentation in python is used to define the structure and the hierachy of code. Unlike many other programming languages that use braces{}
# to delimit blocks of code. Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be
# indented at the same level

# %%
age = 39
if age > 30:
    print("You are above 30 years old.") # see the indentation under the if statement. Python uses indentation to define blocks of code.


print(age)  # Output: 39 this is outside the if statement block, so it will always be executed regardless of the condition.
# Out:
# You are above 30 years old.
# 39

# %% [markdown]
# Line continuation

# %%
total = 10 + 5 + 2  \
+ 3 + 4 + 5
print(total)  # Output: 29 the backslash (\) is used to indicate that the statement continues on the next line. 
              #dont put a space after the backslash. It will give an error.
# Out:
# 29

# %% [markdown]
# Multiple statements on a single line

# %%
x = 5; y = 10; z = 15
print(x, y, z)  # Output: 5 10 15 multiple statements can be written on a single line using semicolons (;).
print(y)  # Output: 10
# Out:
# 5 10 15
# 10

# %% [markdown]
# Understanding semantics

# %%
age = 32
name = "Kiran"

# %%
type (name)  # Output: <class 'str'> the type() function is used to determine the data type of a variable.
# Out:
# str

# %%
type (age)  # Output: <class 'int'> the type() function is used to determine the data type of a variable.
# Out:
# int

# %%
variable = 10
print(type(variable))  # Output: <class 'int'> the type() function is used to determine the data type of a variable.
variable = "Hello"
print(type(variable))  # Output: <class 'str'> the type() function is used to determine the data type of a variable.
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# syntax error

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %% [markdown]
# Correct indentation

# %%
if True:
    print("it is true and correct indentation is used")
    if False:
        print("lets check if it's false")
    print("this is outside the if statement block, so it will always be excuted regardless of the condition.")
print("this also is outside the if statement block, so it will always be executed regardless of the condition.")
# Out:
# it is true and correct indentation is used
# this is outside the if statement block, so it will always be excuted regardless of the condition.
# this also is outside the if statement block, so it will always be executed regardless of the condition.
