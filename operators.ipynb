# %%
# Arithmetic operations 
a = 10
b = 5

result_add = a+b
result_subtract = a-b
result_multiply = a*b
result_divide = a/b # division
result_floor_divide = a//b # floor division
result_modulo = a%b # modulus
result_exp = a**b # Exponentiation


print(result_add)
print(result_subtract)
print(result_multiply)
print(result_divide)
print(result_floor_divide)
print(result_modulo)
print(result_exp)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000
