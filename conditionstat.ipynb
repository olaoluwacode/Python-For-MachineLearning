# %% [markdown]
# Conditional statements and how to use them in python

# %%
## If statement

age = 20 

if age >= 18: 
  print("You are eligible to vote in the elections.")
# Out:
# You are eligible to vote in the elections.

# %%
# else statement
# the else statement executes a block of code if the conddition in the if statement is false.
