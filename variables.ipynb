# %% [markdown]
# Variables \
# Declaring and assigning  variables

# %%
age = 32
height = 1.75
name = "John Doe"
is_student = True

# %% [markdown]
# Printing the variables

# %%
print("Age:", age)
print("Height:", height)
print("Name:", name)
print("Is Student:", is_student)
# Out:
# Age: 32
# Height: 1.75
# Name: John Doe
# Is Student: True

# %% [markdown]
# Invalid variable names

# %%
#  2age = 30
#  first-name = "Alice"
#  @name = "Bob"

# %%
age = 32 #int
height = 1.75 #float
name = "John Doe" #string 
is_student = True #Boolean

print(type(name))
# Out:
# <class 'str'>

# %%
type(height)
# Out:
# float

# %% [markdown]
# Variable convertion

# %%
ages = 123
str(ages)
# Out:
# '123'

# %%
# Dynamic Typing
# Python allows the type of a variable to change as the program executes.
var = 10
print(var, type(var))

var = "Hello"
print(var, type(var))

var = 3.14
print(var, type(var))
# Out:
# 10 <class 'int'>
# Hello <class 'str'>
# 3.14 <class 'float'>

# %% [markdown]
# Input

# %%
age = float(input("Enter your age here: "))
print("Your age is: ", age, type(age))
# Out:
# Your age is:  34.0 <class 'float'>

# %%
### Lets build a simple calculator using the variables that we have learnt

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))  

sum = num1 + num2
difference = num1 -num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 57.0
# Difference: -11.0
# Product: 782.0
# Quotient: 0.6764705882352942
