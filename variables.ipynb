# %% [markdown]
# Variables \
# Declaring and assigning  variables

# %%
age = 32
height = 1.75
name = "John Doe"
is_student = True

# %% [markdown]
# Printing the variables

# %%
print("Age:", age)
print("Height:", height)
print("Name:", name)
print("Is Student:", is_student)
# Out:
# Age: 32
# Height: 1.75
# Name: John Doe
# Is Student: True
